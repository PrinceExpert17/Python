# %% [markdown]
# # Buy and Hold
# - S&P 500
# - Diversification
# - 8-10% annual return

# %%
import pandas_datareader as pdr
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
start = dt.datetime(2005, 1, 1)

sp500 = pdr.get_data_yahoo("^GSPC", start)
sp500.head()
# Out:
#                    High          Low         Open        Close      Volume  \
# Date
# 2005-01-03  1217.800049  1200.319946  1211.920044  1202.079956  1510800000
# 2005-01-04  1205.839966  1185.390015  1202.079956  1188.050049  1721000000
# 2005-01-05  1192.729980  1183.719971  1188.050049  1183.739990  1738900000
# 2005-01-06  1191.630005  1183.270020  1183.739990  1187.890015  1569100000
# 2005-01-07  1192.199951  1182.160034  1187.890015  1186.189941  1477900000
#
#               Adj Close
# Date
# 2005-01-03  1202.079956
# 2005-01-04  1188.050049
# 2005-01-05  1183.739990
# 2005-01-06  1187.890015
# 2005-01-07  1186.189941

# %%
fig, ax = plt.subplots()
sp500['Close'].plot(ax=ax)
#plt.savefig("./image/plot.png", dpi=200)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### The lost decade
# - 2009 - 2019

# %%
sp500['2019'].head()
# Out:
# <ipython-input-6-d62c1f8aa554>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   sp500['2019'].head()
#                    High          Low         Open        Close      Volume  \
# Date
# 2019-01-02  2519.489990  2467.469971  2476.959961  2510.030029  3733160000
# 2019-01-03  2493.139893  2443.959961  2491.919922  2447.889893  3822860000
# 2019-01-04  2538.070068  2474.330078  2474.330078  2531.939941  4213410000
# 2019-01-07  2566.159912  2524.560059  2535.610107  2549.689941  4104710000
# 2019-01-08  2579.820068  2547.560059  2568.110107  2574.409912  4083030000
#
#               Adj Close
# Date
# 2019-01-02  2510.030029
# 2019-01-03  2447.889893
# 2019-01-04  2531.939941
# 2019-01-07  2549.689941
# 2019-01-08  2574.409912

# %%
sp500['2009'].head()
# Out:
# <ipython-input-7-8b53a7528cf6>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   sp500['2009'].head()
#                   High         Low        Open       Close      Volume  \
# Date
# 2009-01-02  934.729980  899.349976  902.989990  931.799988  4048270000
# 2009-01-05  936.630005  919.530029  929.169983  927.450012  5413910000
# 2009-01-06  943.849976  927.280029  931.169983  934.700012  5392620000
# 2009-01-07  927.450012  902.369995  927.450012  906.650024  4704940000
# 2009-01-08  910.000000  896.809998  905.729980  909.729980  4991550000
#
#              Adj Close
# Date
# 2009-01-02  931.799988
# 2009-01-05  927.450012
# 2009-01-06  934.700012
# 2009-01-07  906.650024
# 2009-01-08  909.729980

# %%
fig, ax = plt.subplots()
sp500['Close'].loc[:'2019-01-01'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Performance

# %% [markdown]
# ### GAGR

# %%
data = sp500['Close'].loc['2009':'2018']

# %%
total_return = data.iloc[-1]/data.iloc[0]
total_return
# Out:
# 2.690330683083495

# %%
(data.iloc[-1]/data.iloc[0])**(1/10) - 1
# Out:
# 0.1040292164244021

# %% [markdown]
# ### Drawdown

# %%
rolling_max = data.cummax()
daily_drawdown = data/rolling_max - 1

# %%
max_drawdown = daily_drawdown.cummin().iloc[-1]
max_drawdown
# Out:
# -0.27620624750026523

# %% [markdown]
# ### Project
# - Test the S&P 500 for the period 2010-2020

# %% [markdown]
# #### Step 1
# - get the data

# %%
data = sp500['Close'].loc['2010':'2020']

# %% [markdown]
# #### Step 2
# - Calculate CAGR

# %%
(data.iloc[-1]/data.iloc[0])**(1/10) - 1
# Out:
# 0.1273292130361412

# %% [markdown]
# #### Step 3
# - Calculate max dropdown

# %%
rolling_max = data.cummax()
daily_drawdown = data/rolling_max - 1
max_drawdown = daily_drawdown.cummin().iloc[-1]
max_drawdown
# Out:
# -0.3392496000265327
